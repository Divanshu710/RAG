# %% [markdown]
# RAG Pipelines - Data Ingestion to Vector DB Pipeline

# %%
import os
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# C:\Users\ddivansh\AppData\Local\Temp\ipykernel_33460\1573117932.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 from pathlib import Path
# ----> 3 from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
#       4 from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# File <frozen importlib._bootstrap>:1423, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_community\document_loaders\__init__.py:740, in __getattr__(name)
#     738 def __getattr__(name: str) -> Any:
#     739     if name in _module_lookup:
# --> 740         module = importlib.import_module(_module_lookup[name])
#     741         return getattr(module, name)
#     742     raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_community\document_loaders\pdf.py:28
#      25 from langchain_core.documents import Document
#      26 from langchain_core.utils import get_from_dict_or_env
# ---> 28 from langchain_community.document_loaders.base import BaseLoader
#      29 from langchain_community.document_loaders.blob_loaders import Blob
#      30 from langchain_community.document_loaders.dedoc import DedocBaseLoader
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_community\document_loaders\base.py:1
# ----> 1 from langchain_core.document_loaders import BaseBlobParser, BaseLoader
#       3 __all__ = [
#       4     "BaseBlobParser",
#       5     "BaseLoader",
#       6 ]
#
# File <frozen importlib._bootstrap>:1423, in _handle_fromlist(module, fromlist, import_, recursive)
#    1419         elif x == '*':
#    1420             if not recursive and hasattr(module, '__all__'):
#    1421                 _handle_fromlist(module, module.__all__, import_,
#    1422                                  recursive=True)
# -> 1423         elif not hasattr(module, x):
#    1424             from_name = f'{module.__name__}.{x}'
#    1425             try:
#    1426                 _call_with_frames_removed(import_, from_name)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_core\document_loaders\__init__.py:33, in __getattr__(attr_name)
#      31 def __getattr__(attr_name: str) -> object:
#      32     module_name = _dynamic_imports.get(attr_name)
# ---> 33     result = import_attr(attr_name, module_name, __spec__.parent)
#      34     globals()[attr_name] = result
#      35     return result
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:19
#      16     from langchain_core.documents.base import Blob
#      18 try:
# ---> 19     from langchain_text_splitters import RecursiveCharacterTextSplitter
#      21     _HAS_TEXT_SPLITTERS = True
#      22 except ImportError:
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_text_splitters\__init__.py:39
#      37 from langchain_text_splitters.nltk import NLTKTextSplitter
#      38 from langchain_text_splitters.python import PythonCodeTextSplitter
# ---> 39 from langchain_text_splitters.sentence_transformers import (
#      40     SentenceTransformersTokenTextSplitter,
#      41 )
#      42 from langchain_text_splitters.spacy import SpacyTextSplitter
#      44 __all__ = [
#      45     "CharacterTextSplitter",
#      46     "ElementType",
#    (...)     68     "split_text_on_tokens",
#      69 ]
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\langchain_text_splitters\sentence_transformers.py:11
#       7 from langchain_text_splitters.base import TextSplitter, Tokenizer, split_text_on_tokens
#       9 try:
#      10     # Type ignores needed as long as sentence-transformers doesn't support Python 3.14.
# ---> 11     from sentence_transformers import (  # type: ignore[import-not-found, unused-ignore]
#      12         SentenceTransformer,
#      13     )
#      15     _HAS_SENTENCE_TRANSFORMERS = True
#      16 except ImportError:
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#       5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\backend\load.py:7
#       4 import logging
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#      11 logger = logging.getLogger(__name__)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\configuration_utils.py:32
#      30 from . import __version__
#      31 from .dynamic_module_utils import custom_object_save
# ---> 32 from .generation.configuration_utils import GenerationConfig
#      33 from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#      34 from .modeling_rope_utils import RotaryEmbeddingConfigMixin
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\generation\configuration_utils.py:61
#      57 ALL_CACHE_IMPLEMENTATIONS = ALL_STATIC_CACHE_IMPLEMENTATIONS + DYNAMIC_CACHE_IMPLEMENTATIONS
#      60 if is_torch_available():
# ---> 61     from .logits_process import SynthIDTextWatermarkLogitsProcessor, WatermarkLogitsProcessor
#      64 def _should_warn(outer_attr: str, inner_attr: str, user_set_attributes: set | None) -> bool:
#      65     """Determine if we should raise a warning for the combination `outer_attr` and `inner_attr`, based on whether
#      66     they were provided explicitly, i.e. if they were in `user_set_attributes`.
#      67     For example, if `outer_attr="do_sample"`, the warnings should be suppressed for `inner_attr` flags (e.g. "top_p") that weren't
#      68     explicitly set by the caller. When `do_sample=False` is explicitly required by the user, values such as `top_p` inherited
#      69     from a model's `generation_config.json` are harmless when the user opts for greedy decoding.
#      70     """
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\generation\logits_process.py:21
#      18 from typing import TYPE_CHECKING, Any, cast
#      20 import numpy as np
# ---> 21 import torch
#      23 from .._typing import WhisperGenerationConfigLike
#      24 from ..utils import add_start_docstrings
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\torch\__init__.py:287
#     283                     raise err
#     285         kernel32.SetErrorMode(prev_error_mode)
# --> 287     _load_dll_libraries()
#     288     del _load_dll_libraries
#     291 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     292     # Libraries can either be in
#     293     # path/nvidia/lib_folder/lib or
#     294     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     295     # path/lib_folder/lib
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\torch\__init__.py:270, in _load_dll_libraries()
#     266     err = ctypes.WinError(last_error)
#     267     err.strerror += (
#     268         f' Error loading "{dll}" or one of its dependencies.'
#     269     )
# --> 270     raise err
#     271 elif res is not None:
#     272     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Python_training\RAG\.venv\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
### Read all the pdf's inside the directory
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
            
            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf'
            
            all_documents.extend(documents)
            print(f"  ✓ Loaded {len(documents)} pages")
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents

# Process all PDFs in the data directory
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 2 PDF files to process
#
# Processing: attention.pdf
#   ✓ Loaded 1 pages
#
# Processing: python_intro.pdf
#   ✓ Loaded 3 pages
#
# Total documents loaded: 4

# %%
### Text splitting get into chunks

def split_documents(documents,chunk_size=1000,chunk_overlap=200):
    """Split documents into smaller chunks for better RAG performance"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]
    )
    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
    
    # Show example of a chunk
    if split_docs:
        print(f"\nExample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks=split_documents(all_pdf_documents)
chunks
# Out:
# Split 4 documents into 10 chunks
#
# Example chunk:
# Content: Attention
# Attention Mechanism in Deep Learning
# Overview:
# The attention mechanism allows models to focus on the most relevant parts of input when producing
# each output. It computes a set of weights tha...
# Metadata: {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Attention', 'trapped': '/False', 'source': '..\\data\\attention.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'attention.pdf', 'file_type': 'pdf'}
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Attention', 'trapped': '/False', 'source': '..\\data\\attention.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'attention.pdf', 'file_type': 'pdf'}, page_content='Attention\nAttention Mechanism in Deep Learning\nOverview:\nThe attention mechanism allows models to focus on the most relevant parts of input when producing\neach output. It computes a set of weights that represent the importance of input elements relative to a\ngiven query.\nKey Concepts:\n- Query, Key, Value: Inputs are projected into queries (Q), keys (K), and values (V). Attention scores are\ncomputed from Q and K, then applied to V.\n- Scaled Dot-Product Attention: scores = softmax((Q K^T) / sqrt(d_k)) V. Scaling by sqrt(d_k) stabilizes\ngradients.\n- Multi-Head Attention: multiple attention heads run in parallel with different learned projections, then\nconcatenated. This allows the model to capture different types of relationships.\n- Self-Attention: Q, K, V all come from the same source (e.g., tokens in a sentence). Enables\ncontextualized representations.\nBenefits:\n- Captures long-range dependencies more effectively than RNNs.\n- Parallelizable computations (especially in Transformers).'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Attention', 'trapped': '/False', 'source': '..\\data\\attention.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'attention.pdf', 'file_type': 'pdf'}, page_content='contextualized representations.\nBenefits:\n- Captures long-range dependencies more effectively than RNNs.\n- Parallelizable computations (especially in Transformers).\n- Improves interpretability via attention weights (though weights are not perfect explanations).\nApplications:\n- Machine translation, summarization, question answering, language modeling (Transformers like BERT,\nGPT).\n- Vision: visual attention and Vision Transformers (ViT).\nVariants and Extensions:\n- Additive (Bahdanau) attention: uses a small feed-forward network to compute scores.\n- Relative positional encodings, sparse attention, cross-attention between modalities.\nPractical Tips:\n- Use layer normalization and residual connections with attention layers.\n- Tune head count and model dimension; more heads can help but increase compute.\n- Combine attention with positional encodings to capture order information.\nFurther Reading:\n- "Attention Is All You Need" (Vaswani et al., 2017) — foundational Transformer paper.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Attention', 'trapped': '/False', 'source': '..\\data\\attention.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'source_file': 'attention.pdf', 'file_type': 'pdf'}, page_content='- Combine attention with positional encodings to capture order information.\nFurther Reading:\n- "Attention Is All You Need" (Vaswani et al., 2017) — foundational Transformer paper.\n- Tutorials on scaled dot-product and multi-head attention.\nEOF'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content='Python Intro\nPython is a high-level programming language.\nIt emphasizes readability and simplicity.\nPython supports multiple programming paradigms.\nIt is widely used for scripting and automation.\nPython has an extensive standard library.\nThe language was created by Guido van Rossum.\nPython first appeared in 1991.\nIt uses indentation to define code blocks.\nPython code is often concise and expressive.\nIt has dynamic typing and garbage collection.\nPython supports object-oriented programming.\nIt also supports procedural programming styles.\nFunctional programming is possible in Python.\nPython runs on many operating systems.\nIt is commonly used for web development.\nData science relies heavily on Python.\nPython is popular for machine learning.\nIt is used in scientific computing.\nPython is a good teaching language.\nMany beginners start with Python.\nThe language has a large developer community.\nThere are many open source Python packages.\nPython package management uses pip.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content="Python is a good teaching language.\nMany beginners start with Python.\nThe language has a large developer community.\nThere are many open source Python packages.\nPython package management uses pip.\nVirtual environments isolate Python projects.\nPython code can be written in files or notebooks.\nThe Python REPL allows interactive coding.\nPython supports exception handling.\nIt has built-in data types like lists and dicts.\nStrings, tuples, and sets are also core types.\nPython's list comprehensions are powerful.\nGenerators enable lazy iteration.\nDecorators modify functions and classes.\nContext managers manage resources cleanly.\nPython supports modules and packages.\nThe import system loads reusable code.\nPython is used in web frameworks like Django.\nFlask is a lightweight Python web framework.\nAsyncio enables asynchronous programming.\nPython integrates with databases easily.\nIt can parse and process text data.\nRegular expressions work well in Python.\nPython is used for automation scripts."),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content='Asyncio enables asynchronous programming.\nPython integrates with databases easily.\nIt can parse and process text data.\nRegular expressions work well in Python.\nPython is used for automation scripts.\nIt is popular in DevOps workflows.\nThe language supports unit testing frameworks.\nPytest is a common Python testing tool.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content='Documentation can be generated from Python code.\nPython works with JSON and XML data.\nIt can communicate over networks.\nPython can build command line tools.\nIt is used for desktop applications too.\nPython supports graphics through libraries.\nYou can create GUIs with Python.\nPython handles file input and output.\nIt is used to analyze logs and reports.\nData visualization libraries are available.\nMatplotlib plots data in Python.\nPandas makes data analysis easier.\nNumPy supports numerical computing.\nSciPy offers scientific algorithms.\nPython is used in artificial intelligence.\nNatural language processing often uses Python.\nPython can interact with hardware.\nIt is used in robotics projects.\nMicrocontrollers can run Python variants.\nPython supports unit conversion and math.\nIt is used for simulation and modeling.\nPython is a strong tool for prototypes.\nIt can be used to automate tests.\nPython scripts are easy to maintain.\nThe language evolves with new releases.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content="It is used for simulation and modeling.\nPython is a strong tool for prototypes.\nIt can be used to automate tests.\nPython scripts are easy to maintain.\nThe language evolves with new releases.\nPython 3 is the main supported version.\nBackward compatibility is considered carefully.\nPython code style is guided by PEP 8.\nReadability is a key design goal.\nPython has simple syntax for loops.\nIf statements are straightforward in Python.\nFunctions are defined with def.\nClasses are defined with class.\nPython supports inheritance.\nMetaprogramming is possible in Python.\nThe interpreter executes Python code.\nBytecode is generated for execution.\nPython modules can be compiled.\nIt is often used in cloud environments.\nMany APIs are accessed with Python.\nPython can work with spreadsheets.\nIt is used in finance and analytics.\nPython is useful in education and research.\nThe language encourages clean code practices.\nMany companies use Python in production.\nPython's ecosystem continues to grow."),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content="Python is useful in education and research.\nThe language encourages clean code practices.\nMany companies use Python in production.\nPython's ecosystem continues to grow.\nCommunity resources help new users."),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-02T13:18:16+05:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-02T13:18:16+05:00', 'subject': '(unspecified)', 'title': 'Python Intro', 'trapped': '/False', 'source': '..\\data\\python_intro.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3', 'source_file': 'python_intro.pdf', 'file_type': 'pdf'}, page_content='Conferences and meetups celebrate Python.\nPython code can be shared on GitHub.\nOpen source projects often use Python.\nThe language is supported by many tools.\nEditors and IDEs enhance Python productivity.\nPython remains relevant across domains.\nIt is a versatile and dynamic language.\nPython continues to inspire developers.\nEOF')]

# %% [markdown]
# ### embedding and vectorSToreDB

# %%
import numpy as np
from sentence_transformers import SentenceTransformer 
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 2
#       1 import numpy as np
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 import chromadb
#       4 from chromadb.config import Settings
#       5 import uuid
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\__init__.py:10
#       7 import os
#       8 import warnings
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
#      15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\backend\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
#       5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\sentence_transformers\backend\load.py:7
#       4 import logging
#       5 from pathlib import Path
# ----> 7 from transformers.configuration_utils import PretrainedConfig
#       9 from sentence_transformers.backend.utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save
#      11 logger = logging.getLogger(__name__)
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\configuration_utils.py:32
#      30 from . import __version__
#      31 from .dynamic_module_utils import custom_object_save
# ---> 32 from .generation.configuration_utils import GenerationConfig
#      33 from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#      34 from .modeling_rope_utils import RotaryEmbeddingConfigMixin
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\generation\configuration_utils.py:61
#      57 ALL_CACHE_IMPLEMENTATIONS = ALL_STATIC_CACHE_IMPLEMENTATIONS + DYNAMIC_CACHE_IMPLEMENTATIONS
#      60 if is_torch_available():
# ---> 61     from .logits_process import SynthIDTextWatermarkLogitsProcessor, WatermarkLogitsProcessor
#      64 def _should_warn(outer_attr: str, inner_attr: str, user_set_attributes: set | None) -> bool:
#      65     """Determine if we should raise a warning for the combination `outer_attr` and `inner_attr`, based on whether
#      66     they were provided explicitly, i.e. if they were in `user_set_attributes`.
#      67     For example, if `outer_attr="do_sample"`, the warnings should be suppressed for `inner_attr` flags (e.g. "top_p") that weren't
#      68     explicitly set by the caller. When `do_sample=False` is explicitly required by the user, values such as `top_p` inherited
#      69     from a model's `generation_config.json` are harmless when the user opts for greedy decoding.
#      70     """
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\transformers\generation\logits_process.py:21
#      18 from typing import TYPE_CHECKING, Any, cast
#      20 import numpy as np
# ---> 21 import torch
#      23 from .._typing import WhisperGenerationConfigLike
#      24 from ..utils import add_start_docstrings
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\torch\__init__.py:287
#     283                     raise err
#     285         kernel32.SetErrorMode(prev_error_mode)
# --> 287     _load_dll_libraries()
#     288     del _load_dll_libraries
#     291 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     292     # Libraries can either be in
#     293     # path/nvidia/lib_folder/lib or
#     294     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     295     # path/lib_folder/lib
#
# File c:\Python_training\RAG\.venv\Lib\site-packages\torch\__init__.py:270, in _load_dll_libraries()
#     266     err = ctypes.WinError(last_error)
#     267     err.strerror += (
#     268         f' Error loading "{dll}" or one of its dependencies.'
#     269     )
# --> 270     raise err
#     271 elif res is not None:
#     272     is_loaded = True
#
# OSError: [WinError 1114] A dynamic link library (DLL) initialization routine failed. Error loading "c:\Python_training\RAG\.venv\Lib\site-packages\torch\lib\c10.dll" or one of its dependencies.

# %%
class EmbeddingManager:
    """Handles document embedding generation using SentenceTransformer"""
    
    def __init__(self, model_name: str = "all-MiniLM-L6-v2"):
        """
        Initialize the embedding manager
        
        Args:
            model_name: HuggingFace model name for sentence embeddings
        """
        self.model_name = model_name
        self.model = None
        self._load_model()

    def _load_model(self):
        """Load the SentenceTransformer model"""
        try:
            print(f"Loading embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loaded successfully. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts: List[str]) -> np.ndarray:
        """
        Generate embeddings for a list of texts
        
        Args:
            texts: List of text strings to embed
            
        Returns:
            numpy array of embeddings with shape (len(texts), embedding_dim)
        """
        if not self.model:
            raise ValueError("Model not loaded")
        
        print(f"Generating embeddings for {len(texts)} texts...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings


## initialize the embedding manager

embedding_manager=EmbeddingManager()
embedding_manager
# Out:
# Loading embedding model: all-MiniLM-L6-v2
# Error loading model all-MiniLM-L6-v2: name 'SentenceTransformer' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 46
#      42
#      43
#      44 ## initialize the embedding manager
#      45
# ---> 46 embedding_manager=EmbeddingManager()
#      47 embedding_manager
#
# Cell In[17], line 13, in EmbeddingManager.__init__(self, model_name)
#       9             model_name: HuggingFace model name for sentence embeddings
#      10         """
#      11         self.model_name = model_name
#      12         self.model = None
# ---> 13         self._load_model()
#
# Cell In[17], line 23, in EmbeddingManager._load_model(self)
#      19             self.model = SentenceTransformer(self.model_name)
#      20             print(f"Model loaded successfully. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
#      21         except Exception as e:
#      22             print(f"Error loading model {self.model_name}: {e}")
# ---> 23             raise
#
# NameError: name 'SentenceTransformer' is not defined
